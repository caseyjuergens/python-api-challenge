# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lat=[]
lon= []
cityname=[]
cityid=[]
temp=[]
humidity=[]
cloudy=[]
wind=[]
city_data=[]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units= "imperial"

citycount= 0

query_url =f"{url}appid={weather_api_key}&units={units}&q="


for i, city in enumerate (cities):                       
    try:
        response=requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        cityname.append(response['name'])
        cityid.append(response['id'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudy.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
                     
        print(f"Processing city: {i} city name: {city}")  
        
    #handle exceptions for city that isnt available
    except: 
        print("skip")
        pass
    i+=1
# Out:
# Processing city: 0 city name: lebu
# Processing city: 1 city name: nova olimpia
# Processing city: 2 city name: artyom
# skip
# Processing city: 4 city name: elko
# Processing city: 5 city name: mar del plata
# Processing city: 6 city name: guerrero negro
# Processing city: 7 city name: vostok
# Processing city: 8 city name: cape town
# Processing city: 9 city name: narsaq
# Processing city: 10 city name: faanui
# Processing city: 11 city name: kapaa
# Processing city: 12 city name: mahebourg
# Processing city: 13 city name: arraial do cabo
# Processing city: 14 city name: sitka
# Processing city: 15 city name: mackenzie
# Processing city: 16 city name: upernavik
# Processing city: 17 city name: bluff
# Processing city: 18 city name: cabo san lucas
# Processing city: 19 city name: cockburn town
# Processing city: 20 city name: sioux lookout
# Processing city: 21 city name: victoria
# Processing city: 22 city name: kaitangata
# Processing city: 23 city name: szczytno
# Processing city: 24 city name: takestan
# skip
# Processing city: 26 city name: port elizabeth
# Processing city: 27 city name: severnyy
# skip
# Processing city: 29 city name: ngunguru
# Processing city: 30 city name: mount vernon
# Processing city: 31 city name: puerto ayora
# Processing city: 32 city name: qaanaaq
# Processing city: 33 city name: atambua
# Processing city: 34 city name: atuona
# Processing city: 35 city name: lavrentiya
# Processing city: 36 city name: komsomolskiy
# Processing city: 37 city name: hobart
# Processing city: 38 city name: tuktoyaktuk
# Processing city: 39 city name: korla
# Processing city: 40 city name: cermik
# Processing city: 41 city name: uvalde
# Processing city: 42 city name: auki
# Processing city: 43 city name: mataura
# Processing city: 44 city name: kavieng
# Processing city: 45 city name: meulaboh
# skip
# Processing city: 47 city name: tiksi
# Processing city: 48 city name: luderitz
# Processing city: 49 city name: bredasdorp
# skip
# Processing city: 51 city name: gazojak
# Processing city: 52 city name: talara
# Processing city: 53 city name: batsfjord
# Processing city: 54 city name: farafangana
# Processing city: 55 city name: lewisporte
# Processing city: 56 city name: ushuaia
# Processing city: 57 city name: naze
# skip
# Processing city: 59 city name: busselton
# Processing city: 60 city name: albany
# Processing city: 61 city name: barrow
# Processing city: 62 city name: ostrovnoy
# Processing city: 63 city name: fare
# Processing city: 64 city name: butaritari
# Processing city: 65 city name: iqaluit
# Processing city: 66 city name: talnakh
# Processing city: 67 city name: mokhsogollokh
# Processing city: 68 city name: vanimo
# Processing city: 69 city name: surgut
# Processing city: 70 city name: georgetown
# Processing city: 71 city name: tual
# Processing city: 72 city name: bengkulu
# Processing city: 73 city name: new norfolk
# Processing city: 74 city name: rikitea
# Processing city: 75 city name: leningradskiy
# Processing city: 76 city name: havre-saint-pierre
# Processing city: 77 city name: murgab
# Processing city: 78 city name: humaita
# Processing city: 79 city name: northam
# Processing city: 80 city name: mount gambier
# Processing city: 81 city name: sabha
# skip
# Processing city: 83 city name: hopelchen
# Processing city: 84 city name: mushie
# skip
# skip
# Processing city: 87 city name: pemba
# Processing city: 88 city name: punta arenas
# Processing city: 89 city name: bilma
# Processing city: 90 city name: port alfred
# Processing city: 91 city name: andenes
# Processing city: 92 city name: murchison
# Processing city: 93 city name: yumen
# Processing city: 94 city name: esperance
# Processing city: 95 city name: masumbwe
# Processing city: 96 city name: saldanha
# Processing city: 97 city name: tahta
# Processing city: 98 city name: longyearbyen
# Processing city: 99 city name: pisco
# Processing city: 100 city name: gwadar
# Processing city: 101 city name: saskylakh
# Processing city: 102 city name: hermanus
# Processing city: 103 city name: bathsheba
# Processing city: 104 city name: guadix
# Processing city: 105 city name: ribeira grande
# Processing city: 106 city name: jamestown
# Processing city: 107 city name: constitucion
# Processing city: 108 city name: nikolskoye
# Processing city: 109 city name: east london
# Processing city: 110 city name: pathein
# Processing city: 111 city name: katobu
# Processing city: 112 city name: nowogard
# Processing city: 113 city name: chuy
# skip
# Processing city: 115 city name: tasiilaq
# Processing city: 116 city name: santiago de cao
# Processing city: 117 city name: kodiak
# Processing city: 118 city name: pangobilian
# Processing city: 119 city name: hilo
# skip
# Processing city: 121 city name: avarua
# Processing city: 122 city name: santa marta
# Processing city: 123 city name: colac
# Processing city: 124 city name: lorengau
# Processing city: 125 city name: olinda
# Processing city: 126 city name: airai
# skip
# Processing city: 128 city name: bingol
# Processing city: 129 city name: joshimath
# Processing city: 130 city name: cayenne
# Processing city: 131 city name: chokurdakh
# Processing city: 132 city name: lagoa
# Processing city: 133 city name: guadalupe y calvo
# skip
# Processing city: 135 city name: mocuba
# Processing city: 136 city name: kaa-khem
# Processing city: 137 city name: clyde river
# Processing city: 138 city name: sakakah
# Processing city: 139 city name: gold coast
# Processing city: 140 city name: naryan-mar
# Processing city: 141 city name: lac du bonnet
# Processing city: 142 city name: shingu
# Processing city: 143 city name: ha giang
# Processing city: 144 city name: kisangani
# Processing city: 145 city name: datong
# Processing city: 146 city name: adrar
# Processing city: 147 city name: castro
# Processing city: 148 city name: askiz
# Processing city: 149 city name: nanortalik
# skip
# Processing city: 151 city name: tabas
# Processing city: 152 city name: touros
# Processing city: 153 city name: vaini
# Processing city: 154 city name: loandjili
# skip
# Processing city: 156 city name: chinhoyi
# Processing city: 157 city name: bani
# Processing city: 158 city name: namibe
# Processing city: 159 city name: cagliliog
# Processing city: 160 city name: katsuura
# Processing city: 161 city name: bulgan
# Processing city: 162 city name: broome
# Processing city: 163 city name: sikasso
# Processing city: 164 city name: tuatapere
# Processing city: 165 city name: saint-philippe
# Processing city: 166 city name: willowmore
# Processing city: 167 city name: limaong
# Processing city: 168 city name: pevek
# Processing city: 169 city name: dikson
# Processing city: 170 city name: isla vista
# Processing city: 171 city name: paragominas
# Processing city: 172 city name: brownsville
# Processing city: 173 city name: yellowknife
# skip
# Processing city: 175 city name: quatre cocos
# Processing city: 176 city name: hualmay
# Processing city: 177 city name: grand gaube
# Processing city: 178 city name: sao joao da barra
# Processing city: 179 city name: puri
# Processing city: 180 city name: launceston
# Processing city: 181 city name: saint-augustin
# Processing city: 182 city name: saint george
# Processing city: 183 city name: san patricio
# skip
# Processing city: 185 city name: san policarpo
# skip
# skip
# Processing city: 188 city name: isangel
# Processing city: 189 city name: ambilobe
# Processing city: 190 city name: kovdor
# Processing city: 191 city name: alofi
# Processing city: 192 city name: ugoofaaru
# Processing city: 193 city name: maarianhamina
# Processing city: 194 city name: pierre
# Processing city: 195 city name: grindavik
# Processing city: 196 city name: provideniya
# Processing city: 197 city name: samarinda
# Processing city: 198 city name: karratha
# Processing city: 199 city name: brae
# Processing city: 200 city name: novopokrovka
# Processing city: 201 city name: jiutai
# Processing city: 202 city name: prainha
# Processing city: 203 city name: acarau
# Processing city: 204 city name: tilichiki
# Processing city: 205 city name: poum
# Processing city: 206 city name: tautira
# Processing city: 207 city name: eyl
# Processing city: 208 city name: svetlogorsk
# Processing city: 209 city name: barra patuca
# skip
# skip
# Processing city: 212 city name: gouyave
# skip
# skip
# Processing city: 215 city name: hasaki
# Processing city: 216 city name: makakilo city
# Processing city: 217 city name: padang
# Processing city: 218 city name: sisimiut
# Processing city: 219 city name: ayagoz
# Processing city: 220 city name: hithadhoo
# Processing city: 221 city name: cherskiy
# Processing city: 222 city name: kodino
# Processing city: 223 city name: nieves
# Processing city: 224 city name: fairbanks
# Processing city: 225 city name: dicabisagan
# Processing city: 226 city name: marand
# Processing city: 227 city name: bonthe
# Processing city: 228 city name: hervey bay
# Processing city: 229 city name: kaminskiy
# Processing city: 230 city name: mandurah
# Processing city: 231 city name: thompson
# Processing city: 232 city name: keti bandar
# Processing city: 233 city name: kiruna
# Processing city: 234 city name: la tuque
# Processing city: 235 city name: deputatskiy
# Processing city: 236 city name: vao
# Processing city: 237 city name: ituiutaba
# Processing city: 238 city name: geraldton
# skip
# Processing city: 240 city name: owando
# Processing city: 241 city name: buenaventura
# Processing city: 242 city name: port hedland
# Processing city: 243 city name: banes
# Processing city: 244 city name: kruisfontein
# Processing city: 245 city name: plavinas
# Processing city: 246 city name: moranbah
# Processing city: 247 city name: puerto carreno
# Processing city: 248 city name: beringovskiy
# skip
# Processing city: 250 city name: souillac
# Processing city: 251 city name: cuamba
# Processing city: 252 city name: khangarh
# Processing city: 253 city name: young
# Processing city: 254 city name: mweka
# Processing city: 255 city name: cidreira
# Processing city: 256 city name: grajau
# Processing city: 257 city name: aswan
# Processing city: 258 city name: tutoia
# Processing city: 259 city name: coquimbo
# Processing city: 260 city name: slave lake
# Processing city: 261 city name: lillooet
# Processing city: 262 city name: vega de alatorre
# Processing city: 263 city name: champasak
# Processing city: 264 city name: gat
# Processing city: 265 city name: itambacuri
# Processing city: 266 city name: saint-joseph
# Processing city: 267 city name: lompoc
# skip
# Processing city: 269 city name: booue
# Processing city: 270 city name: tahe
# Processing city: 271 city name: arlit
# skip
# Processing city: 273 city name: manadhoo
# Processing city: 274 city name: okhotsk
# Processing city: 275 city name: coihaique
# Processing city: 276 city name: yei
# Processing city: 277 city name: innisfail
# Processing city: 278 city name: mehamn
# skip
# Processing city: 280 city name: ancud
# Processing city: 281 city name: aripuana
# Processing city: 282 city name: bowen
# Processing city: 283 city name: sao gabriel da cachoeira
# Processing city: 284 city name: santana do acarau
# Processing city: 285 city name: kahului
# Processing city: 286 city name: kutum
# Processing city: 287 city name: waipawa
# Processing city: 288 city name: taoudenni
# Processing city: 289 city name: ullapool
# Processing city: 290 city name: okha
# Processing city: 291 city name: caravelas
# Processing city: 292 city name: yerbogachen
# skip
# Processing city: 294 city name: norman wells
# Processing city: 295 city name: zhezkazgan
# skip
# Processing city: 297 city name: kochi
# Processing city: 298 city name: sinegorye
# Processing city: 299 city name: klaksvik
# Processing city: 300 city name: vila velha
# Processing city: 301 city name: plettenberg bay
# Processing city: 302 city name: virginia beach
# Processing city: 303 city name: doume
# skip
# Processing city: 305 city name: myitkyina
# Processing city: 306 city name: khatanga
# Processing city: 307 city name: nouadhibou
# Processing city: 308 city name: liyang
# Processing city: 309 city name: san buenaventura
# Processing city: 310 city name: sabang
# Processing city: 311 city name: oyama
# Processing city: 312 city name: muros
# Processing city: 313 city name: vancouver
# Processing city: 314 city name: benguela
# Processing city: 315 city name: jishou
# Processing city: 316 city name: salalah
# Processing city: 317 city name: broken hill
# skip
# Processing city: 319 city name: talcahuano
# Processing city: 320 city name: kavaratti
# Processing city: 321 city name: atbasar
# Processing city: 322 city name: heiligenhafen
# Processing city: 323 city name: nemuro
# Processing city: 324 city name: kiliya
# Processing city: 325 city name: richards bay
# Processing city: 326 city name: teeli
# Processing city: 327 city name: petlawad
# Processing city: 328 city name: aitape
# Processing city: 329 city name: diego de almagro
# Processing city: 330 city name: biak
# Processing city: 331 city name: nakamura
# skip
# Processing city: 333 city name: la ronge
# Processing city: 334 city name: darnah
# Processing city: 335 city name: palmer
# Processing city: 336 city name: camacha
# Processing city: 337 city name: rohnert park
# skip
# Processing city: 339 city name: bardiyah
# Processing city: 340 city name: chunoyar
# Processing city: 341 city name: carnarvon
# Processing city: 342 city name: bambanglipuro
# Processing city: 343 city name: sao filipe
# Processing city: 344 city name: carupano
# Processing city: 345 city name: mitchell
# skip
# Processing city: 347 city name: lykhivka
# Processing city: 348 city name: saint-saulve
# Processing city: 349 city name: santa cruz de la palma
# Processing city: 350 city name: tampere
# Processing city: 351 city name: haines junction
# Processing city: 352 city name: kamaishi
# Processing city: 353 city name: amahai
# Processing city: 354 city name: san cristobal
# Processing city: 355 city name: port blair
# Processing city: 356 city name: weligama
# Processing city: 357 city name: katangli
# Processing city: 358 city name: ucluelet
# Processing city: 359 city name: cuervos
# Processing city: 360 city name: necochea
# Processing city: 361 city name: southbridge
# Processing city: 362 city name: kamien pomorski
# Processing city: 363 city name: bodden town
# Processing city: 364 city name: qaqortoq
# Processing city: 365 city name: miri
# Processing city: 366 city name: eureka
# skip
# Processing city: 368 city name: zaruma
# Processing city: 369 city name: svetlaya
# Processing city: 370 city name: coolum beach
# Processing city: 371 city name: voyvozh
# Processing city: 372 city name: anopino
# skip
# Processing city: 374 city name: kloulklubed
# Processing city: 375 city name: salinopolis
# Processing city: 376 city name: mao
# Processing city: 377 city name: yar-sale
# Processing city: 378 city name: waingapu
# Processing city: 379 city name: pergamino
# Processing city: 380 city name: high level
# skip
# Processing city: 382 city name: ivanovka
# Processing city: 383 city name: kaeo
# Processing city: 384 city name: chateaubelair
# Processing city: 385 city name: zaragoza
# Processing city: 386 city name: sholokhove
# Processing city: 387 city name: olga
# Processing city: 388 city name: talakan
# Processing city: 389 city name: paamiut
# Processing city: 390 city name: mandalgovi
# Processing city: 391 city name: kathu
# Processing city: 392 city name: ponta do sol
# skip
# Processing city: 394 city name: raga
# Processing city: 395 city name: bajil
# Processing city: 396 city name: saint-pierre
# Processing city: 397 city name: college
# Processing city: 398 city name: benjamin constant
# Processing city: 399 city name: fukue
# Processing city: 400 city name: esna
# Processing city: 401 city name: tocopilla
# Processing city: 402 city name: garissa
# Processing city: 403 city name: whitianga
# Processing city: 404 city name: san jose
# Processing city: 405 city name: yulara
# Processing city: 406 city name: zaria
# Processing city: 407 city name: torbay
# Processing city: 408 city name: clinton
# Processing city: 409 city name: ati
# Processing city: 410 city name: ilhabela
# Processing city: 411 city name: walvis bay
# Processing city: 412 city name: bonavista
# Processing city: 413 city name: petauke
# Processing city: 414 city name: balykshi
# Processing city: 415 city name: la asuncion
# Processing city: 416 city name: yaan
# Processing city: 417 city name: vadso
# Processing city: 418 city name: ararat
# Processing city: 419 city name: aban
# Processing city: 420 city name: uige
# skip
# Processing city: 422 city name: laje
# Processing city: 423 city name: toppenish
# Processing city: 424 city name: pangkalanbuun
# Processing city: 425 city name: codrington
# Processing city: 426 city name: nelson bay
# Processing city: 427 city name: paso de carrasco
# skip
# Processing city: 429 city name: marihatag
# Processing city: 430 city name: iquitos
# Processing city: 431 city name: nampula
# Processing city: 432 city name: mapiri
# Processing city: 433 city name: zonguldak
# Processing city: 434 city name: mineiros
# Processing city: 435 city name: lasa
# Processing city: 436 city name: veraval
# Processing city: 437 city name: birjand
# Processing city: 438 city name: sfantu gheorghe
# Processing city: 439 city name: orlik
# Processing city: 440 city name: hamilton
# Processing city: 441 city name: santa isabel do rio negro
# Processing city: 442 city name: olyka
# Processing city: 443 city name: dongsheng
# Processing city: 444 city name: teguldet
# Processing city: 445 city name: poso
# Processing city: 446 city name: lumby
# Processing city: 447 city name: lircay
# Processing city: 448 city name: bria
# Processing city: 449 city name: basse
# Processing city: 450 city name: bubaque
# Processing city: 451 city name: marsabit
# Processing city: 452 city name: xichang
# Processing city: 453 city name: tonota
# Processing city: 454 city name: pemangkat
# Processing city: 455 city name: azuaga
# Processing city: 456 city name: gobabis
# Processing city: 457 city name: beisfjord
# skip
# Processing city: 459 city name: kitimat
# Processing city: 460 city name: yichang
# Processing city: 461 city name: yining
# Processing city: 462 city name: ortigueira
# Processing city: 463 city name: saurimo
# Processing city: 464 city name: kudahuvadhoo
# Processing city: 465 city name: usinsk
# Processing city: 466 city name: mulege
# Processing city: 467 city name: nara
# Processing city: 468 city name: karaton
# Processing city: 469 city name: mangrol
# Processing city: 470 city name: cabedelo
# Processing city: 471 city name: pacific grove
# Processing city: 472 city name: nome
# Processing city: 473 city name: ewa beach
# Processing city: 474 city name: hay river
# Processing city: 475 city name: sulangan
# Processing city: 476 city name: san luis
# skip
# Processing city: 478 city name: malanje
# Processing city: 479 city name: aykhal
# Processing city: 480 city name: princeton
# Processing city: 481 city name: dunedin
# Processing city: 482 city name: valle hermoso
# Processing city: 483 city name: ulladulla
# Processing city: 484 city name: ereymentau
# Processing city: 485 city name: herat
# Processing city: 486 city name: nerchinskiy zavod
# Processing city: 487 city name: severo-kurilsk
# Processing city: 488 city name: agdas
# Processing city: 489 city name: bethel
# Processing city: 490 city name: ambon
# Processing city: 491 city name: ternate
# Processing city: 492 city name: dingle
# Processing city: 493 city name: zhangye
# skip
# skip
# Processing city: 496 city name: najran
# Processing city: 497 city name: hauterive
# Processing city: 498 city name: port-gentil
# Processing city: 499 city name: shima
# Processing city: 500 city name: kamina
# Processing city: 501 city name: petropavlovsk-kamchatskiy
# Processing city: 502 city name: sao miguel do araguaia
# Processing city: 503 city name: salta
# skip
# skip
# Processing city: 506 city name: kiamba
# Processing city: 507 city name: urengoy
# Processing city: 508 city name: princes town
# skip
# Processing city: 510 city name: pitiquito
# Processing city: 511 city name: guanhaes
# Processing city: 512 city name: saint-francois
# Processing city: 513 city name: gamba
# Processing city: 514 city name: port macquarie
# Processing city: 515 city name: pingxiang
# Processing city: 516 city name: abnub
# Processing city: 517 city name: srednekolymsk
# Processing city: 518 city name: hami
# Processing city: 519 city name: fort smith
# Processing city: 520 city name: petatlan
# Processing city: 521 city name: ambulu
# Processing city: 522 city name: minab
# Processing city: 523 city name: itinga
# skip
# Processing city: 525 city name: ust-abakan
# Processing city: 526 city name: hofn
# Processing city: 527 city name: tateyama
# Processing city: 528 city name: samana
# Processing city: 529 city name: posevnaya
# Processing city: 530 city name: bathurst
# Processing city: 531 city name: atar
# Processing city: 532 city name: nyurba
# Processing city: 533 city name: waxahachie
# skip
# Processing city: 535 city name: noo
# Processing city: 536 city name: thinadhoo
# Processing city: 537 city name: kupang
# Processing city: 538 city name: leiyang
# Processing city: 539 city name: kamenka
# Processing city: 540 city name: gladstone
# Processing city: 541 city name: bambous virieux
# Processing city: 542 city name: yangambi
# Processing city: 543 city name: conde
# Processing city: 544 city name: tongliao
# Processing city: 545 city name: potiskum
# skip
# Processing city: 547 city name: vila franca do campo
# Processing city: 548 city name: zomba
# Processing city: 549 city name: taungdwingyi
# Processing city: 550 city name: yantzaza
# Processing city: 551 city name: mogadishu
# Processing city: 552 city name: honningsvag
# skip
# Processing city: 554 city name: alice springs
# Processing city: 555 city name: requena
# Processing city: 556 city name: khor
# Processing city: 557 city name: ban dung
# Processing city: 558 city name: lima
# Processing city: 559 city name: biltine
# Processing city: 560 city name: hobyo
# Processing city: 561 city name: almaznyy
# Processing city: 562 city name: kirakira
# Processing city: 563 city name: panguna
# Processing city: 564 city name: kurilsk
# Processing city: 565 city name: takaka
# Processing city: 566 city name: belaya gora
# Processing city: 567 city name: san jose de sisa
# Processing city: 568 city name: itarema
# Processing city: 569 city name: jaguaruana
# Processing city: 570 city name: half moon bay
# Processing city: 571 city name: blagoyevo
# Processing city: 572 city name: sorland
# Processing city: 573 city name: mudigere
# Processing city: 574 city name: fort morgan
# Processing city: 575 city name: sonoma
# Processing city: 576 city name: santo andre
# Processing city: 577 city name: koslan
# Processing city: 578 city name: port lincoln
# Processing city: 579 city name: ambrolauri
# Processing city: 580 city name: banda aceh
# Processing city: 581 city name: ixtapa
# Processing city: 582 city name: zhigansk
# skip
# Processing city: 584 city name: bakaly
# Processing city: 585 city name: tura
# Processing city: 586 city name: sarrebourg
# Processing city: 587 city name: russell
# Processing city: 588 city name: inongo
# Processing city: 589 city name: aklavik
# Processing city: 590 city name: makariv
# Processing city: 591 city name: kaniama
# Processing city: 592 city name: inverness
# Processing city: 593 city name: athabasca
# Processing city: 594 city name: dod ballapur
# Processing city: 595 city name: cairns
# Processing city: 596 city name: birao
# Processing city: 597 city name: kenora
# Processing city: 598 city name: lumphat
# Processing city: 599 city name: luau
# Processing city: 600 city name: havelock
# Processing city: 601 city name: riyadh
# Processing city: 602 city name: parker
# Processing city: 603 city name: jiayuguan
# Processing city: 604 city name: fortuna
# Processing city: 605 city name: upington
# Processing city: 606 city name: kerman
# Processing city: 607 city name: perth
# Processing city: 608 city name: porto novo
# Processing city: 609 city name: hovd
# Processing city: 610 city name: vaitape
# Processing city: 611 city name: ajdabiya
# Processing city: 612 city name: mecca
# Processing city: 613 city name: evensk
# Processing city: 614 city name: redcar
# Processing city: 615 city name: kobryn
# skip
# Processing city: 617 city name: nazare

# %%
city_dict={
    "city": cityname,
    "city id": cityid,
    "Latitude": lat,
    "Longitude": lon,
    "Temperature": temp,
    "Humidity": humidity,
    "Cloudy": cloudy,
    "Wind Speed (mph)": wind}
city_df= pd.DataFrame(city_dict)
city_df.head(20)
# Out:
#             city  city id  Latitude  Longitude  Temperature  Humidity  Cloudy  \
# 0   Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 1   Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 2   Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 3   Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 4   Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 5   Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 6   Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 7   Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 8   Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 9   Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 10  Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 11  Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 12  Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 13  Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 14  Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 15  Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 16  Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 17  Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 18  Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
# 19  Punta Arenas  3874787    -53.15   -70.9167         46.2        93      75
#
#     Wind Speed (mph)
# 0               4.61
# 1               4.61
# 2               4.61
# 3               4.61
# 4               4.61
# 5               4.61
# 6               4.61
# 7               4.61
# 8               4.61
# 9               4.61
# 10              4.61
# 11              4.61
# 12              4.61
# 13              4.61
# 14              4.61
# 15              4.61
# 16              4.61
# 17              4.61
# 18              4.61
# 19              4.61

# %%
#cannot for the life of me figure out why the first city repeats itself 600x. just gonna
#delete the dupicates and come back to this. hopefully. 
clean_city_df= city_df.drop_duplicates(subset=["city"])

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
clean_city_df.to_csv("City_Data.csv")

# %%
clean_city_df.head()
# Out:
#              city  city id  Latitude  Longitude  Temperature  Humidity  \
# 0    Punta Arenas  3874787  -53.1500   -70.9167        46.20        93
# 618          Lebu  3883457  -37.6167   -73.6500        52.32        76
# 619  Nova Olímpia  3456137  -14.7972   -57.2881        79.11        54
# 620        Artyom   587207   40.4723    50.3330        55.40        76
# 621          Elko  5703673   41.0002  -115.5012        61.14        13
#
#      Cloudy  Wind Speed (mph)
# 0        75              4.61
# 618      89              2.30
# 619      41              2.59
# 620      20             18.41
# 621       1             16.11

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_city_df.loc[clean_city_df["Humidity"]== 100]
# Out:
#                  city  city id  Latitude  Longitude  Temperature  Humidity  \
# 625         Cape Town  3369157  -33.9258    18.4232        56.48       100
# 688   Havre-St-Pierre  5972291   50.2334   -63.5986        37.40       100
# 870             Ancud  3899695  -41.8697   -73.8203        47.89       100
# 933           Tampere   634963   61.4991    23.7871        35.55       100
# 1046         Cabedelo  3404558   -6.9811   -34.8339        78.80       100
# 1111            Conde  3385077   -7.2597   -34.9075        78.80       100
# 1155          Makariv   702337   50.4641    29.8113        48.07       100
#
#       Cloudy  Wind Speed (mph)
# 625       90             12.66
# 688       90             19.57
# 870       75              8.05
# 933       75              2.30
# 1046       0              6.91
# 1111       0              6.91
# 1155      75              6.33

# %%
#  Get the indices of cities that have humidity over 100%.
clean_city_df.index[clean_city_df["Humidity"]== 100].tolist()
# Out:
# [625, 688, 870, 933, 1046, 1111, 1155]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data= clean_city_df.drop(index= [625,688,870,933,1111,1155])
clean_city_data
# Out:
#                       city  city id  Latitude  Longitude  Temperature  \
# 0             Punta Arenas  3874787  -53.1500   -70.9167        46.20
# 618                   Lebu  3883457  -37.6167   -73.6500        52.32
# 619           Nova Olímpia  3456137  -14.7972   -57.2881        79.11
# 620                 Artyom   587207   40.4723    50.3330        55.40
# 621                   Elko  5703673   41.0002  -115.5012        61.14
# ...                    ...      ...       ...        ...          ...
# 1177  Makkah al Mukarramah   104515   21.4267    39.8261        84.42
# 1178                Evensk  2125693   61.9500   159.2333        27.50
# 1179                Redcar  2639563   54.6166    -1.0600        42.76
# 1180                Kobryn   627145   52.2138    24.3564        37.15
# 1181                Nazaré  3456366  -13.0350   -39.0144        74.37
#
#       Humidity  Cloudy  Wind Speed (mph)
# 0           93      75              4.61
# 618         76      89              2.30
# 619         54      41              2.59
# 620         76      20             18.41
# 621         13       1             16.11
# ...        ...     ...               ...
# 1177        37      74              4.25
# 1178        90      94              3.04
# 1179        48      93              1.99
# 1180        77      14             11.23
# 1181        95      87              3.13
#
# [558 rows x 8 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
