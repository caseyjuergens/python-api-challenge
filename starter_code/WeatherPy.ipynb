# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_df=pd.DataFrame(cities)
cities_df
# Out:
#                   0
# 0      saint-joseph
# 1         peterhead
# 2      san patricio
# 3             vaini
# 4         roebourne
# ..              ...
# 620           arman
# 621  elesbao veloso
# 622   puerto madero
# 623          tibati
# 624       abu dhabi
#
# [625 rows x 1 columns]

# %%
cities_df['City']= cities
cities_df["Latitude"]=""
cities_df['Longitude']= ""
cities_df['ID'] = ""
cities_df['Temperature']= ""
cities_df['Humidity']= ""
cities_df['Cloudiness']= ""
cities_df['Wind Speed (mph)']= ""

cities_df.head()
# Out:
#               0          City Latitude Longitude ID Temperature Humidity  \
# 0  saint-joseph  saint-joseph
# 1     peterhead     peterhead
# 2  san patricio  san patricio
# 3         vaini         vaini
# 4     roebourne     roebourne
#
#   Cloudiness Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units= "imperial"

citycount= 0

query_url =f"{url}appid={weather_api_key}&units={units}&q="


for index, row in cities_df.iterrows():
    city=row['City']
    try:
        response =requests.get(query_url + city).json()
        cities_df.loc[index, "Latitude"] =response['coord']['lat']
        cities_df.loc[index, "Longitude"]=response['coord']['lon']
        cities_df.loc[index, "ID"] =response['id']
        cities_df.loc[index, "Temperature"] =response['main']['temp']
        cities_df.loc[index, "Humidity"] =response['main']['humidity']
        cities_df.loc[index, "Cloudiness"] =response['clouds']['all']
        cities_df.loc[index, "Wind Speed (mph)"]=response['wind']['speed']
                     
        print(f"Processing city: {citycount} city name: {city}")  
        
    #handle exceptions for city that isnt available
    except: 
        print("skip")
        pass
    citycount+=1
# Out:
# Processing city: 0 city name: saint-joseph
# Processing city: 1 city name: peterhead
# Processing city: 2 city name: san patricio
# Processing city: 3 city name: vaini
# Processing city: 4 city name: roebourne
# Processing city: 5 city name: mango
# Processing city: 6 city name: gusau
# Processing city: 7 city name: mahebourg
# Processing city: 8 city name: albany
# Processing city: 9 city name: bredasdorp
# skip
# Processing city: 11 city name: ballaghaderreen
# Processing city: 12 city name: caravelas
# Processing city: 13 city name: kijang
# Processing city: 14 city name: bandarbeyla
# Processing city: 15 city name: puerto ayora
# Processing city: 16 city name: kapaa
# Processing city: 17 city name: atuona
# Processing city: 18 city name: busselton
# Processing city: 19 city name: severo-kurilsk
# Processing city: 20 city name: bow island
# Processing city: 21 city name: tura
# Processing city: 22 city name: castro
# Processing city: 23 city name: tutoia
# Processing city: 24 city name: hamilton
# Processing city: 25 city name: norsup
# Processing city: 26 city name: karachi
# Processing city: 27 city name: hermanus
# Processing city: 28 city name: novokruchininskiy
# Processing city: 29 city name: alexandria
# skip
# Processing city: 31 city name: kulunda
# Processing city: 32 city name: whitehorse
# Processing city: 33 city name: charters towers
# Processing city: 34 city name: bluff
# Processing city: 35 city name: nouadhibou
# Processing city: 36 city name: provideniya
# Processing city: 37 city name: kincardine
# Processing city: 38 city name: bremerton
# Processing city: 39 city name: cabo san lucas
# Processing city: 40 city name: upernavik
# Processing city: 41 city name: ushuaia
# Processing city: 42 city name: cidreira
# Processing city: 43 city name: la ronge
# Processing city: 44 city name: rikitea
# Processing city: 45 city name: broome
# Processing city: 46 city name: tuktoyaktuk
# Processing city: 47 city name: punta arenas
# skip
# Processing city: 49 city name: adrar
# Processing city: 50 city name: butaritari
# Processing city: 51 city name: kodiak
# Processing city: 52 city name: hambantota
# Processing city: 53 city name: muros
# Processing city: 54 city name: tigbinan
# Processing city: 55 city name: te anau
# Processing city: 56 city name: malmesbury
# Processing city: 57 city name: jumla
# Processing city: 58 city name: puerto madryn
# Processing city: 59 city name: roma
# Processing city: 60 city name: avarua
# Processing city: 61 city name: kirovskiy
# Processing city: 62 city name: mar del plata
# Processing city: 63 city name: port hedland
# Processing city: 64 city name: ostrovnoy
# Processing city: 65 city name: huntsville
# Processing city: 66 city name: ribeira grande
# Processing city: 67 city name: norman wells
# Processing city: 68 city name: hobart
# Processing city: 69 city name: isangel
# Processing city: 70 city name: port maria
# Processing city: 71 city name: lazaro cardenas
# Processing city: 72 city name: tiksi
# skip
# Processing city: 74 city name: el prat de llobregat
# Processing city: 75 city name: fortuna
# Processing city: 76 city name: port elizabeth
# Processing city: 77 city name: mataura
# Processing city: 78 city name: vaitape
# Processing city: 79 city name: ust-nera
# Processing city: 80 city name: yenagoa
# Processing city: 81 city name: qaanaaq
# Processing city: 82 city name: dongsheng
# Processing city: 83 city name: rocha
# Processing city: 84 city name: bukachacha
# Processing city: 85 city name: porto novo
# Processing city: 86 city name: port alfred
# Processing city: 87 city name: alyangula
# Processing city: 88 city name: pacific grove
# skip
# Processing city: 90 city name: juneau
# Processing city: 91 city name: cobija
# Processing city: 92 city name: saint-philippe
# Processing city: 93 city name: yar-sale
# Processing city: 94 city name: latung
# Processing city: 95 city name: tchollire
# Processing city: 96 city name: mingaora
# Processing city: 97 city name: port lincoln
# Processing city: 98 city name: kargasok
# Processing city: 99 city name: tasiilaq
# Processing city: 100 city name: sinnamary
# Processing city: 101 city name: americus
# Processing city: 102 city name: new norfolk
# Processing city: 103 city name: barrow
# Processing city: 104 city name: iquique
# Processing city: 105 city name: hilo
# Processing city: 106 city name: seddon
# Processing city: 107 city name: mount isa
# Processing city: 108 city name: chuy
# Processing city: 109 city name: ammon
# Processing city: 110 city name: tual
# Processing city: 111 city name: shirgaon
# Processing city: 112 city name: east london
# Processing city: 113 city name: sucua
# Processing city: 114 city name: saskylakh
# Processing city: 115 city name: eureka
# skip
# skip
# Processing city: 118 city name: presidencia roque saenz pena
# Processing city: 119 city name: lagoa
# Processing city: 120 city name: dikson
# Processing city: 121 city name: thompson
# Processing city: 122 city name: shushtar
# Processing city: 123 city name: chokurdakh
# Processing city: 124 city name: bengkulu
# Processing city: 125 city name: victoria
# Processing city: 126 city name: gat
# Processing city: 127 city name: husavik
# Processing city: 128 city name: geraldton
# Processing city: 129 city name: palora
# Processing city: 130 city name: jining
# Processing city: 131 city name: narsaq
# Processing city: 132 city name: antofagasta
# Processing city: 133 city name: paulo ramos
# Processing city: 134 city name: guerrero negro
# Processing city: 135 city name: port hardy
# Processing city: 136 city name: tuatapere
# Processing city: 137 city name: ayagoz
# Processing city: 138 city name: bilibino
# Processing city: 139 city name: hithadhoo
# Processing city: 140 city name: atasu
# Processing city: 141 city name: the valley
# Processing city: 142 city name: erzin
# Processing city: 143 city name: los alamos
# skip
# Processing city: 145 city name: dukhovshchina
# Processing city: 146 city name: meulaboh
# Processing city: 147 city name: yulara
# Processing city: 148 city name: soyo
# Processing city: 149 city name: bambanglipuro
# Processing city: 150 city name: buraydah
# Processing city: 151 city name: liwale
# Processing city: 152 city name: college
# Processing city: 153 city name: mangrol
# Processing city: 154 city name: saint anthony
# Processing city: 155 city name: namtsy
# skip
# Processing city: 157 city name: torbat-e jam
# Processing city: 158 city name: chake chake
# Processing city: 159 city name: harper
# Processing city: 160 city name: bonavista
# Processing city: 161 city name: cape town
# Processing city: 162 city name: flers
# Processing city: 163 city name: jamestown
# Processing city: 164 city name: georgetown
# Processing city: 165 city name: gilgit
# Processing city: 166 city name: yellowknife
# Processing city: 167 city name: coquimbo
# Processing city: 168 city name: quatre cocos
# Processing city: 169 city name: misratah
# Processing city: 170 city name: ribeira brava
# Processing city: 171 city name: vanimo
# Processing city: 172 city name: cherskiy
# Processing city: 173 city name: kaitangata
# Processing city: 174 city name: saint george
# skip
# Processing city: 176 city name: ilulissat
# Processing city: 177 city name: bereda
# Processing city: 178 city name: nishihara
# Processing city: 179 city name: honiara
# Processing city: 180 city name: turukhansk
# Processing city: 181 city name: lebu
# Processing city: 182 city name: ozernovskiy
# Processing city: 183 city name: anchorage
# Processing city: 184 city name: grand gaube
# Processing city: 185 city name: estelle
# skip
# Processing city: 187 city name: nantucket
# Processing city: 188 city name: iqaluit
# Processing city: 189 city name: nikolskoye
# Processing city: 190 city name: ridgefield
# Processing city: 191 city name: cayenne
# Processing city: 192 city name: borogontsy
# Processing city: 193 city name: yerbogachen
# Processing city: 194 city name: sisimiut
# Processing city: 195 city name: souillac
# Processing city: 196 city name: palmer
# Processing city: 197 city name: kupang
# Processing city: 198 city name: portsmouth
# Processing city: 199 city name: talnakh
# Processing city: 200 city name: nouakchott
# Processing city: 201 city name: kavieng
# Processing city: 202 city name: pevek
# Processing city: 203 city name: kasempa
# Processing city: 204 city name: brazzaville
# Processing city: 205 city name: diego de almagro
# Processing city: 206 city name: arraial do cabo
# Processing city: 207 city name: benguela
# skip
# Processing city: 209 city name: soma
# Processing city: 210 city name: singarayakonda
# Processing city: 211 city name: charlestown
# Processing city: 212 city name: sorland
# Processing city: 213 city name: luanda
# skip
# Processing city: 215 city name: telimele
# Processing city: 216 city name: lavrentiya
# Processing city: 217 city name: mpulungu
# skip
# Processing city: 219 city name: kudahuvadhoo
# Processing city: 220 city name: bilma
# Processing city: 221 city name: kieta
# Processing city: 222 city name: rawson
# Processing city: 223 city name: yaan
# Processing city: 224 city name: jinchang
# Processing city: 225 city name: wanaka
# Processing city: 226 city name: ancud
# skip
# Processing city: 228 city name: coihaique
# Processing city: 229 city name: lompoc
# Processing city: 230 city name: yelan
# Processing city: 231 city name: ipil
# Processing city: 232 city name: chernigovka
# Processing city: 233 city name: muscat
# Processing city: 234 city name: codrington
# Processing city: 235 city name: pisco
# Processing city: 236 city name: porto walter
# Processing city: 237 city name: yatou
# Processing city: 238 city name: santiago
# skip
# Processing city: 240 city name: port augusta
# Processing city: 241 city name: puerto escondido
# Processing city: 242 city name: san cristobal
# Processing city: 243 city name: angicos
# Processing city: 244 city name: chifeng
# Processing city: 245 city name: eyl
# skip
# Processing city: 247 city name: ponta delgada
# Processing city: 248 city name: zhigalovo
# Processing city: 249 city name: castelnaudary
# Processing city: 250 city name: piranshahr
# Processing city: 251 city name: rosehearty
# Processing city: 252 city name: beringovskiy
# Processing city: 253 city name: nuuk
# Processing city: 254 city name: avera
# Processing city: 255 city name: nautla
# Processing city: 256 city name: raudeberg
# Processing city: 257 city name: bathsheba
# Processing city: 258 city name: bandar
# Processing city: 259 city name: nicoya
# Processing city: 260 city name: smithers
# Processing city: 261 city name: gonen
# Processing city: 262 city name: alofi
# Processing city: 263 city name: dinguiraye
# Processing city: 264 city name: lamar
# Processing city: 265 city name: bambous virieux
# Processing city: 266 city name: jalu
# Processing city: 267 city name: leningradskiy
# Processing city: 268 city name: lata
# skip
# Processing city: 270 city name: marienburg
# Processing city: 271 city name: baiyin
# Processing city: 272 city name: angouleme
# Processing city: 273 city name: pitogo
# Processing city: 274 city name: mikhaylovskoye
# Processing city: 275 city name: porbandar
# skip
# Processing city: 277 city name: khatanga
# Processing city: 278 city name: havoysund
# Processing city: 279 city name: rio casca
# Processing city: 280 city name: farsund
# skip
# Processing city: 282 city name: bagdarin
# skip
# Processing city: 284 city name: bethel
# Processing city: 285 city name: yairipok
# Processing city: 286 city name: zanjan
# Processing city: 287 city name: dunmore town
# skip
# Processing city: 289 city name: sarangani
# Processing city: 290 city name: taoudenni
# Processing city: 291 city name: san quintin
# Processing city: 292 city name: luganville
# Processing city: 293 city name: alice springs
# Processing city: 294 city name: esperance
# Processing city: 295 city name: cabedelo
# Processing city: 296 city name: skjervoy
# Processing city: 297 city name: fairbanks
# Processing city: 298 city name: pasighat
# Processing city: 299 city name: waipawa
# Processing city: 300 city name: srednekolymsk
# Processing city: 301 city name: hit
# Processing city: 302 city name: essau
# Processing city: 303 city name: banjar
# Processing city: 304 city name: bogatoye
# Processing city: 305 city name: amapa
# Processing city: 306 city name: kavaratti
# Processing city: 307 city name: mala
# Processing city: 308 city name: baraya
# Processing city: 309 city name: santa isabel do rio negro
# skip
# Processing city: 311 city name: ornskoldsvik
# Processing city: 312 city name: amazar
# skip
# Processing city: 314 city name: pangai
# Processing city: 315 city name: thai binh
# Processing city: 316 city name: puerto leguizamo
# Processing city: 317 city name: marsh harbour
# Processing city: 318 city name: mokhsogollokh
# Processing city: 319 city name: sefophe
# Processing city: 320 city name: luderitz
# Processing city: 321 city name: bongandanga
# Processing city: 322 city name: vestmannaeyjar
# Processing city: 323 city name: cueramaro
# Processing city: 324 city name: westport
# Processing city: 325 city name: hasaki
# skip
# Processing city: 327 city name: makat
# Processing city: 328 city name: berlevag
# Processing city: 329 city name: pangoa
# Processing city: 330 city name: marystown
# Processing city: 331 city name: asfi
# Processing city: 332 city name: morros
# Processing city: 333 city name: ponta do sol
# Processing city: 334 city name: shebunino
# Processing city: 335 city name: dali
# Processing city: 336 city name: mount gambier
# Processing city: 337 city name: axim
# Processing city: 338 city name: mindelo
# Processing city: 339 city name: palu
# Processing city: 340 city name: mahibadhoo
# Processing city: 341 city name: thinadhoo
# Processing city: 342 city name: tarko-sale
# Processing city: 343 city name: sabang
# Processing city: 344 city name: atar
# Processing city: 345 city name: douentza
# Processing city: 346 city name: makokou
# Processing city: 347 city name: kanke
# Processing city: 348 city name: celestun
# Processing city: 349 city name: acarau
# Processing city: 350 city name: dickinson
# Processing city: 351 city name: terrace
# Processing city: 352 city name: sulecin
# Processing city: 353 city name: brae
# Processing city: 354 city name: atherton
# Processing city: 355 city name: grindavik
# Processing city: 356 city name: inyonga
# Processing city: 357 city name: plettenberg bay
# Processing city: 358 city name: matinhos
# Processing city: 359 city name: sibolga
# Processing city: 360 city name: carnarvon
# Processing city: 361 city name: oxapampa
# Processing city: 362 city name: kant
# Processing city: 363 city name: acari
# Processing city: 364 city name: galesburg
# skip
# Processing city: 366 city name: vanavara
# Processing city: 367 city name: klaksvik
# Processing city: 368 city name: verkhnyaya inta
# Processing city: 369 city name: yankton
# Processing city: 370 city name: cap malheureux
# Processing city: 371 city name: toamasina
# Processing city: 372 city name: coihueco
# Processing city: 373 city name: zyryanka
# Processing city: 374 city name: acapulco
# Processing city: 375 city name: krasnoobsk
# Processing city: 376 city name: tazovskiy
# Processing city: 377 city name: taman
# Processing city: 378 city name: graham
# Processing city: 379 city name: bellavista
# Processing city: 380 city name: faanui
# Processing city: 381 city name: kruisfontein
# Processing city: 382 city name: aklavik
# skip
# Processing city: 384 city name: vila do maio
# Processing city: 385 city name: kulhudhuffushi
# Processing city: 386 city name: nileshwar
# Processing city: 387 city name: magistralnyy
# Processing city: 388 city name: bafoulabe
# Processing city: 389 city name: mezen
# Processing city: 390 city name: kutum
# Processing city: 391 city name: sonoita
# Processing city: 392 city name: deer lake
# Processing city: 393 city name: maniitsoq
# Processing city: 394 city name: naze
# Processing city: 395 city name: hastings
# Processing city: 396 city name: esso
# Processing city: 397 city name: sao joao da barra
# Processing city: 398 city name: heubach
# Processing city: 399 city name: leshukonskoye
# Processing city: 400 city name: orapa
# Processing city: 401 city name: wyszkow
# Processing city: 402 city name: motala
# Processing city: 403 city name: miri
# Processing city: 404 city name: bireun
# Processing city: 405 city name: champerico
# Processing city: 406 city name: san andres
# Processing city: 407 city name: tevaitoa
# skip
# Processing city: 409 city name: moose factory
# Processing city: 410 city name: tilichiki
# Processing city: 411 city name: mirnyy
# Processing city: 412 city name: metlika
# Processing city: 413 city name: dingle
# Processing city: 414 city name: asau
# Processing city: 415 city name: helena
# Processing city: 416 city name: pushkino
# Processing city: 417 city name: kualakapuas
# Processing city: 418 city name: hami
# Processing city: 419 city name: touros
# Processing city: 420 city name: kropotkin
# Processing city: 421 city name: hervey bay
# Processing city: 422 city name: saint-georges
# Processing city: 423 city name: umm lajj
# Processing city: 424 city name: saldanha
# Processing city: 425 city name: keuruu
# Processing city: 426 city name: kirakira
# Processing city: 427 city name: aba
# Processing city: 428 city name: chernyshevskiy
# Processing city: 429 city name: hashtgerd
# skip
# Processing city: 431 city name: hampton
# Processing city: 432 city name: carupano
# Processing city: 433 city name: mazatlan
# Processing city: 434 city name: sumenep
# Processing city: 435 city name: bud
# Processing city: 436 city name: seymchan
# Processing city: 437 city name: kandrian
# Processing city: 438 city name: french harbor
# Processing city: 439 city name: evensk
# skip
# Processing city: 441 city name: quirinopolis
# Processing city: 442 city name: sao filipe
# Processing city: 443 city name: banda aceh
# Processing city: 444 city name: pokhara
# Processing city: 445 city name: slobozia
# Processing city: 446 city name: ketchikan
# Processing city: 447 city name: north bend
# skip
# Processing city: 449 city name: peniche
# Processing city: 450 city name: vila franca do campo
# Processing city: 451 city name: olinda
# skip
# Processing city: 453 city name: ginda
# Processing city: 454 city name: wanxian
# Processing city: 455 city name: kahului
# Processing city: 456 city name: brakpan
# Processing city: 457 city name: pangody
# Processing city: 458 city name: quixada
# Processing city: 459 city name: longyearbyen
# Processing city: 460 city name: nabire
# Processing city: 461 city name: valcourt
# Processing city: 462 city name: miranda
# Processing city: 463 city name: baijiantan
# Processing city: 464 city name: davidson
# Processing city: 465 city name: tonekabon
# Processing city: 466 city name: puerto del rosario
# Processing city: 467 city name: ndele
# Processing city: 468 city name: bocana de paiwas
# Processing city: 469 city name: xining
# Processing city: 470 city name: san borja
# Processing city: 471 city name: kouango
# Processing city: 472 city name: kyren
# Processing city: 473 city name: winslow
# Processing city: 474 city name: ucluelet
# Processing city: 475 city name: kholodnyy
# Processing city: 476 city name: makamba
# Processing city: 477 city name: vardo
# skip
# Processing city: 479 city name: coracora
# Processing city: 480 city name: katherine
# Processing city: 481 city name: torbay
# Processing city: 482 city name: hirado
# Processing city: 483 city name: tateyama
# Processing city: 484 city name: hobyo
# Processing city: 485 city name: sinop
# Processing city: 486 city name: ratnapura
# Processing city: 487 city name: huarmey
# Processing city: 488 city name: jiblah
# Processing city: 489 city name: aparecida
# Processing city: 490 city name: cockburn town
# Processing city: 491 city name: buctzotz
# Processing city: 492 city name: petropavlovsk-kamchatskiy
# Processing city: 493 city name: kuusamo
# Processing city: 494 city name: brokopondo
# Processing city: 495 city name: laohekou
# Processing city: 496 city name: nunchia
# Processing city: 497 city name: kysyl-syr
# Processing city: 498 city name: los corrales de buelna
# Processing city: 499 city name: sao felix do xingu
# Processing city: 500 city name: aswan
# Processing city: 501 city name: along
# Processing city: 502 city name: suntar
# Processing city: 503 city name: carangola
# Processing city: 504 city name: emborion
# Processing city: 505 city name: fort nelson
# Processing city: 506 city name: komsomolets
# Processing city: 507 city name: nemuro
# Processing city: 508 city name: birin
# Processing city: 509 city name: ngunguru
# Processing city: 510 city name: valley city
# Processing city: 511 city name: weiser
# Processing city: 512 city name: saint-pierre
# Processing city: 513 city name: fandriana
# Processing city: 514 city name: santa vitoria do palmar
# Processing city: 515 city name: tamiahua
# Processing city: 516 city name: freeport
# Processing city: 517 city name: avesta
# skip
# Processing city: 519 city name: opuwo
# Processing city: 520 city name: okhotsk
# Processing city: 521 city name: safaga
# Processing city: 522 city name: bairiki
# Processing city: 523 city name: urusha
# Processing city: 524 city name: trogir
# Processing city: 525 city name: lincoln
# Processing city: 526 city name: fuling
# Processing city: 527 city name: poum
# Processing city: 528 city name: krasnoselkup
# Processing city: 529 city name: salym
# Processing city: 530 city name: comodoro rivadavia
# Processing city: 531 city name: malko tarnovo
# Processing city: 532 city name: katsuura
# Processing city: 533 city name: kuching
# Processing city: 534 city name: hargeysa
# Processing city: 535 city name: doha
# Processing city: 536 city name: santa clara
# Processing city: 537 city name: emerald
# Processing city: 538 city name: yarkovo
# Processing city: 539 city name: hofn
# Processing city: 540 city name: sangmelima
# Processing city: 541 city name: pathein
# Processing city: 542 city name: rio gallegos
# Processing city: 543 city name: komsomolskiy
# Processing city: 544 city name: ciudad bolivar
# Processing city: 545 city name: santiago del estero
# Processing city: 546 city name: kinablangan
# Processing city: 547 city name: san cayetano
# Processing city: 548 city name: baoying
# Processing city: 549 city name: wanning
# Processing city: 550 city name: podor
# Processing city: 551 city name: aitape
# Processing city: 552 city name: half moon bay
# Processing city: 553 city name: dalvik
# Processing city: 554 city name: muli
# skip
# Processing city: 556 city name: airai
# Processing city: 557 city name: jacareacanga
# Processing city: 558 city name: clyde river
# Processing city: 559 city name: soller
# Processing city: 560 city name: manchar
# Processing city: 561 city name: sioux lookout
# Processing city: 562 city name: port blair
# Processing city: 563 city name: tiznit
# Processing city: 564 city name: burley
# Processing city: 565 city name: point pleasant
# skip
# Processing city: 567 city name: linkou
# Processing city: 568 city name: karaton
# skip
# Processing city: 570 city name: talas
# Processing city: 571 city name: caxito
# Processing city: 572 city name: hay river
# Processing city: 573 city name: san vicente
# Processing city: 574 city name: laguna de perlas
# Processing city: 575 city name: iranshahr
# Processing city: 576 city name: machilipatnam
# Processing city: 577 city name: nome
# Processing city: 578 city name: golden
# Processing city: 579 city name: christchurch
# Processing city: 580 city name: mattru
# Processing city: 581 city name: zhuhai
# skip
# Processing city: 583 city name: gannan
# Processing city: 584 city name: progreso
# Processing city: 585 city name: wuchang
# Processing city: 586 city name: makakilo city
# Processing city: 587 city name: oktyabrskoye
# Processing city: 588 city name: scottsbluff
# Processing city: 589 city name: tarazona
# Processing city: 590 city name: sembe
# Processing city: 591 city name: hvide sande
# Processing city: 592 city name: mazara del vallo
# Processing city: 593 city name: salalah
# Processing city: 594 city name: lubumbashi
# skip
# Processing city: 596 city name: walvis bay
# Processing city: 597 city name: san carlos de bariloche
# Processing city: 598 city name: monroe
# Processing city: 599 city name: darnah
# Processing city: 600 city name: bantou
# Processing city: 601 city name: oktyabrskiy
# Processing city: 602 city name: hirara
# Processing city: 603 city name: saint-leu
# Processing city: 604 city name: port-gentil
# skip
# Processing city: 606 city name: bedesa
# Processing city: 607 city name: nalut
# Processing city: 608 city name: wundanyi
# Processing city: 609 city name: talcahuano
# Processing city: 610 city name: kizukuri
# Processing city: 611 city name: gao
# skip
# skip
# Processing city: 614 city name: pochutla
# Processing city: 615 city name: viedma
# Processing city: 616 city name: fethiye
# Processing city: 617 city name: chegdomyn
# Processing city: 618 city name: saharanpur
# Processing city: 619 city name: vladivostok
# Processing city: 620 city name: arman
# Processing city: 621 city name: elesbao veloso
# Processing city: 622 city name: puerto madero
# Processing city: 623 city name: tibati
# Processing city: 624 city name: abu dhabi

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv("City_Data.csv")

# %%
cities_df.head(10)
# Out:
#               0          City Latitude Longitude       ID Temperature  \
# 0  saint-joseph  saint-joseph -21.3667   55.6167  6690296        70.3
# 1     peterhead     peterhead  57.5058   -1.7981  2640351       41.45
# 2  san patricio  san patricio   28.017  -97.5169  4726521       71.53
# 3         vaini         vaini    -21.2    -175.2  4032243          86
# 4     roebourne     roebourne -20.7833   117.133  2062276       81.84
# 5         mango         mango  27.9797  -82.3065  4163318        72.5
# 6         gusau         gusau  12.1628    6.6614  2339937       87.22
# 7     mahebourg     mahebourg -20.4081      57.7   934322        75.2
# 8        albany        albany  42.6001  -73.9662  5106841       38.12
# 9    bredasdorp    bredasdorp -34.5322   20.0403  1015776          50
#
#   Humidity Cloudiness Wind Speed (mph)
# 0       83         90            10.36
# 1       93         58              2.3
# 2       83         90            16.11
# 3       79         75             6.91
# 4       21          0            17.87
# 5       56          1             4.61
# 6       35         11             6.13
# 7       94         75            18.41
# 8       49         17            13.09
# 9       93          6              2.3

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_df.loc[cities_df["Humidity"]== 100]
# Out:
#               0        City Latitude Longitude       ID Temperature Humidity  \
# 52   hambantota  hambantota   6.1241   81.1185  1244926          77      100
# 56   malmesbury  malmesbury -33.4608   18.7271  3364346       56.17      100
# 160   bonavista   bonavista  48.6499  -53.1147  5905393       41.65      100
# 161   cape town   cape town -33.9258   18.4232  3369157       56.41      100
# 177      bereda      bereda  43.2686   -7.5406  3105522        46.9      100
# 198  portsmouth  portsmouth   50.799   -1.0913  2639996       42.01      100
# 226       ancud       ancud -41.8697  -73.8203  3899695       47.07      100
# 294   esperance   esperance -33.8667     121.9  2071860        55.4      100
# 358    matinhos    matinhos -25.8175  -48.5428  3457455       55.33      100
# 372    coihueco    coihueco -36.6167  -71.8333  3894406        53.6      100
# 425      keuruu      keuruu  62.2667      24.7   652977       34.29      100
# 481      torbay      torbay  47.6666  -52.7314  6167817       42.35      100
#
#     Cloudiness Wind Speed (mph)
# 52          20             4.61
# 56          90            14.97
# 160        100            14.97
# 161         90            14.97
# 177         22             1.99
# 198          3               14
# 226         90             4.61
# 294        100            12.66
# 358         75              2.3
# 372         20              1.7
# 425         90             3.44
# 481         90            33.38

# %%
#  Get the indices of cities that have humidity over 100%.
cities_df.index[cities_df["Humidity"]== 100].tolist()
# Out:
# [52, 56, 160, 161, 177, 198, 226, 294, 358, 372, 425, 481]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data= cities_df.drop(index= [52, 56, 160, 161, 177, 198, 226, 294, 358, 372, 425, 481])
clean_city_data
# Out:
#                   0            City Latitude Longitude       ID Temperature  \
# 0      saint-joseph    saint-joseph -21.3667   55.6167  6690296        70.3
# 1         peterhead       peterhead  57.5058   -1.7981  2640351       41.45
# 2      san patricio    san patricio   28.017  -97.5169  4726521       71.53
# 3             vaini           vaini    -21.2    -175.2  4032243          86
# 4         roebourne       roebourne -20.7833   117.133  2062276       81.84
# ..              ...             ...      ...       ...      ...         ...
# 620           arman           arman     59.7   150.167  2127060       31.86
# 621  elesbao veloso  elesbao veloso  -6.2019  -42.1403  3400920       72.81
# 622   puerto madero   puerto madero  14.7208  -92.4215  3520989          86
# 623          tibati          tibati   6.4667   12.6333  2221530       66.79
# 624       abu dhabi       abu dhabi  24.4667   54.3667   292968       79.57
#
#     Humidity Cloudiness Wind Speed (mph)
# 0         83         90            10.36
# 1         93         58              2.3
# 2         83         90            16.11
# 3         79         75             6.91
# 4         21          0            17.87
# ..       ...        ...              ...
# 620       98        100             4.21
# 621       93        100             0.49
# 622       74         75             6.91
# 623       94        100             1.48
# 624       53          0              2.3
#
# [613 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
