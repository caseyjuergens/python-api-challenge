# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lat=[]
lon= []
cityname=[]
cityid=[]
temp=[]
humidity=[]
cloudy=[]
wind=[]
city_data=[]

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units= "imperial"

citycount= 0
query_url =f"{url}appid={weather_api_key}&units={units}&q="
for i, city in enumerate (cities):                       
    try:
        response=requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        cityname.append(response['name'])
        cityid.append(response['id'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudy.append(response['clouds'])
        wind.append(response['wind']['speed'])
                     
        print(f"Processing city: {i} city name: {city}")     
    except:
        print("skip")
        pass
    i+=1
# Out:
# Processing city: 0 city name: bluff
# Processing city: 1 city name: khatanga
# Processing city: 2 city name: busselton
# Processing city: 3 city name: rikitea
# Processing city: 4 city name: lavrentiya
# Processing city: 5 city name: punta arenas
# Processing city: 6 city name: senanga
# Processing city: 7 city name: beidao
# Processing city: 8 city name: tasiilaq
# Processing city: 9 city name: nikolskoye
# Processing city: 10 city name: ilulissat
# Processing city: 11 city name: mahebourg
# Processing city: 12 city name: rurrenabaque
# Processing city: 13 city name: yellowknife
# Processing city: 14 city name: barrow
# Processing city: 15 city name: new norfolk
# skip
# Processing city: 17 city name: provideniya
# Processing city: 18 city name: akureyri
# Processing city: 19 city name: lagoa
# Processing city: 20 city name: cocorit
# Processing city: 21 city name: tuktoyaktuk
# Processing city: 22 city name: tarakan
# skip
# Processing city: 24 city name: hasaki
# Processing city: 25 city name: inta
# Processing city: 26 city name: castro
# Processing city: 27 city name: torbay
# Processing city: 28 city name: santa isabel
# Processing city: 29 city name: pimentel
# Processing city: 30 city name: georgetown
# Processing city: 31 city name: bredasdorp
# Processing city: 32 city name: vallenar
# Processing city: 33 city name: hobart
# Processing city: 34 city name: caconde
# Processing city: 35 city name: bajil
# Processing city: 36 city name: ushuaia
# Processing city: 37 city name: albany
# Processing city: 38 city name: boma
# Processing city: 39 city name: chokurdakh
# Processing city: 40 city name: port alfred
# Processing city: 41 city name: longyearbyen
# Processing city: 42 city name: butaritari
# Processing city: 43 city name: port augusta
# Processing city: 44 city name: cape town
# skip
# Processing city: 46 city name: kawalu
# Processing city: 47 city name: aksarka
# Processing city: 48 city name: hamilton
# Processing city: 49 city name: gazalkent
# Processing city: 50 city name: goma
# Processing city: 51 city name: kapaa
# Processing city: 52 city name: lerwick
# Processing city: 53 city name: cabo san lucas
# Processing city: 54 city name: thompson
# Processing city: 55 city name: ilhabela
# Processing city: 56 city name: ahipara
# Processing city: 57 city name: grimshaw
# skip
# Processing city: 59 city name: haimen
# Processing city: 60 city name: meulaboh
# Processing city: 61 city name: mataura
# Processing city: 62 city name: upernavik
# Processing city: 63 city name: qasigiannguit
# Processing city: 64 city name: huntsville
# Processing city: 65 city name: vitim
# Processing city: 66 city name: jamestown
# Processing city: 67 city name: ostrovnoy
# skip
# Processing city: 69 city name: luwuk
# Processing city: 70 city name: fortuna
# Processing city: 71 city name: henties bay
# Processing city: 72 city name: kodiak
# Processing city: 73 city name: bundaberg
# Processing city: 74 city name: hermanus
# skip
# Processing city: 76 city name: kaitangata
# Processing city: 77 city name: lensk
# Processing city: 78 city name: vaini
# Processing city: 79 city name: thinadhoo
# Processing city: 80 city name: kaeo
# Processing city: 81 city name: perambalur
# Processing city: 82 city name: ponta delgada
# Processing city: 83 city name: mundo nuevo
# Processing city: 84 city name: sri madhopur
# Processing city: 85 city name: terre haute
# Processing city: 86 city name: qaanaaq
# Processing city: 87 city name: faya
# Processing city: 88 city name: pacific grove
# Processing city: 89 city name: guerrero negro
# Processing city: 90 city name: mar del plata
# Processing city: 91 city name: saskylakh
# Processing city: 92 city name: sao filipe
# Processing city: 93 city name: sokoto
# Processing city: 94 city name: ahar
# Processing city: 95 city name: makakilo city
# Processing city: 96 city name: salvador
# Processing city: 97 city name: kirakira
# Processing city: 98 city name: ginda
# Processing city: 99 city name: severodvinsk
# Processing city: 100 city name: coihaique
# Processing city: 101 city name: puerto ayora
# Processing city: 102 city name: souillac
# Processing city: 103 city name: urengoy
# Processing city: 104 city name: landeck
# Processing city: 105 city name: lucapa
# Processing city: 106 city name: baiquan
# Processing city: 107 city name: ndola
# Processing city: 108 city name: tiksi
# Processing city: 109 city name: bethel
# Processing city: 110 city name: omsukchan
# Processing city: 111 city name: carnarvon
# Processing city: 112 city name: rorvik
# Processing city: 113 city name: vardo
# skip
# Processing city: 115 city name: buta
# Processing city: 116 city name: dikson
# Processing city: 117 city name: huadian
# Processing city: 118 city name: sarakhs
# Processing city: 119 city name: sabalgarh
# Processing city: 120 city name: pavlodar
# Processing city: 121 city name: aswan
# Processing city: 122 city name: bathsheba
# Processing city: 123 city name: konice
# Processing city: 124 city name: miraflores
# Processing city: 125 city name: mount isa
# Processing city: 126 city name: avarua
# Processing city: 127 city name: abu samrah
# Processing city: 128 city name: muros
# Processing city: 129 city name: jiujiang
# Processing city: 130 city name: chicama
# skip
# Processing city: 132 city name: coahuayana
# Processing city: 133 city name: khandyga
# Processing city: 134 city name: vila franca do campo
# skip
# Processing city: 136 city name: arman
# Processing city: 137 city name: port hardy
# skip
# Processing city: 139 city name: sawtell
# Processing city: 140 city name: leon
# Processing city: 141 city name: fatezh
# Processing city: 142 city name: bengkulu
# Processing city: 143 city name: denpasar
# Processing city: 144 city name: chapais
# Processing city: 145 city name: inyonga
# Processing city: 146 city name: luckenwalde
# Processing city: 147 city name: sainte-marie
# Processing city: 148 city name: katsuura
# Processing city: 149 city name: tahta
# Processing city: 150 city name: severo-kurilsk
# Processing city: 151 city name: east london
# Processing city: 152 city name: rundu
# Processing city: 153 city name: hilton head island
# Processing city: 154 city name: hofn
# Processing city: 155 city name: saint george
# Processing city: 156 city name: vanimo
# Processing city: 157 city name: camacha
# Processing city: 158 city name: amuntai
# Processing city: 159 city name: ponta do sol
# Processing city: 160 city name: port lincoln
# Processing city: 161 city name: kapit
# Processing city: 162 city name: dzilam gonzalez
# Processing city: 163 city name: parkes
# Processing city: 164 city name: charters towers
# Processing city: 165 city name: lebu
# Processing city: 166 city name: palani
# Processing city: 167 city name: nizwa
# Processing city: 168 city name: loucovice
# Processing city: 169 city name: totness
# Processing city: 170 city name: korablino
# Processing city: 171 city name: kungurtug
# Processing city: 172 city name: stephenville
# Processing city: 173 city name: asau
# Processing city: 174 city name: vagur
# Processing city: 175 city name: norman wells
# Processing city: 176 city name: waitati
# Processing city: 177 city name: ust-kut
# Processing city: 178 city name: geraldton
# Processing city: 179 city name: oussouye
# skip
# Processing city: 181 city name: grand gaube
# Processing city: 182 city name: waipawa
# Processing city: 183 city name: kahului
# Processing city: 184 city name: porto-vecchio
# skip
# Processing city: 186 city name: pervoye maya
# Processing city: 187 city name: olinda
# Processing city: 188 city name: codrington
# Processing city: 189 city name: iqaluit
# Processing city: 190 city name: kushiro
# Processing city: 191 city name: chuy
# Processing city: 192 city name: san jose
# Processing city: 193 city name: ondangwa
# Processing city: 194 city name: itaueira
# Processing city: 195 city name: banyo
# Processing city: 196 city name: nova varos
# Processing city: 197 city name: linoan
# Processing city: 198 city name: itanagar
# Processing city: 199 city name: dubbo
# Processing city: 200 city name: savannah bight
# Processing city: 201 city name: hilo
# Processing city: 202 city name: mwanza
# Processing city: 203 city name: yulara
# skip
# Processing city: 205 city name: killam
# Processing city: 206 city name: jacmel
# Processing city: 207 city name: tawau
# Processing city: 208 city name: atuona
# Processing city: 209 city name: smithers
# Processing city: 210 city name: port elizabeth
# Processing city: 211 city name: morgan city
# Processing city: 212 city name: aberdeen
# Processing city: 213 city name: sorong
# Processing city: 214 city name: broken hill
# Processing city: 215 city name: lyngseidet
# Processing city: 216 city name: brainerd
# Processing city: 217 city name: rassvet
# skip
# Processing city: 219 city name: sao sebastiao
# Processing city: 220 city name: conil
# Processing city: 221 city name: ribeira grande
# Processing city: 222 city name: saint-philippe
# Processing city: 223 city name: isangel
# Processing city: 224 city name: asfi
# Processing city: 225 city name: faanui
# Processing city: 226 city name: deputatskiy
# Processing city: 227 city name: cidreira
# Processing city: 228 city name: pangnirtung
# Processing city: 229 city name: bambous virieux
# Processing city: 230 city name: cabedelo
# Processing city: 231 city name: yaan
# Processing city: 232 city name: saint-joseph
# Processing city: 233 city name: akyab
# Processing city: 234 city name: skibbereen
# Processing city: 235 city name: karaton
# Processing city: 236 city name: half moon bay
# Processing city: 237 city name: isla vista
# Processing city: 238 city name: riyadh
# Processing city: 239 city name: chittur
# Processing city: 240 city name: shaunavon
# Processing city: 241 city name: inirida
# Processing city: 242 city name: cape coast
# Processing city: 243 city name: dingle
# Processing city: 244 city name: yar-sale
# Processing city: 245 city name: bourail
# Processing city: 246 city name: arraial do cabo
# Processing city: 247 city name: nanortalik
# Processing city: 248 city name: cherskiy
# Processing city: 249 city name: catabola
# Processing city: 250 city name: salinopolis
# Processing city: 251 city name: kulhudhuffushi
# Processing city: 252 city name: peniche
# Processing city: 253 city name: masterton
# Processing city: 254 city name: chake chake
# Processing city: 255 city name: zyryanka
# Processing city: 256 city name: ulladulla
# Processing city: 257 city name: itoman
# Processing city: 258 city name: pointe michel
# Processing city: 259 city name: moussoro
# Processing city: 260 city name: champerico
# Processing city: 261 city name: chulym
# Processing city: 262 city name: verkhoyansk
# Processing city: 263 city name: neiafu
# Processing city: 264 city name: luancheng
# Processing city: 265 city name: sciacca
# Processing city: 266 city name: krivosheino
# Processing city: 267 city name: aden
# Processing city: 268 city name: santa helena de goias
# Processing city: 269 city name: chikwawa
# Processing city: 270 city name: karratha
# skip
# Processing city: 272 city name: santa isabel do rio negro
# Processing city: 273 city name: banda aceh
# Processing city: 274 city name: novovarshavka
# Processing city: 275 city name: sherbakul
# Processing city: 276 city name: evensk
# Processing city: 277 city name: naliya
# Processing city: 278 city name: san carlos de bariloche
# Processing city: 279 city name: dunedin
# Processing city: 280 city name: sorgun
# Processing city: 281 city name: watertown
# Processing city: 282 city name: longyan
# Processing city: 283 city name: gorom-gorom
# Processing city: 284 city name: itupiranga
# Processing city: 285 city name: mehamn
# Processing city: 286 city name: lorengau
# Processing city: 287 city name: abalak
# Processing city: 288 city name: tanete
# Processing city: 289 city name: treinta y tres
# Processing city: 290 city name: dalby
# Processing city: 291 city name: santa marta de tormes
# Processing city: 292 city name: namibe
# Processing city: 293 city name: sobolevo
# Processing city: 294 city name: sisimiut
# Processing city: 295 city name: mitsamiouli
# Processing city: 296 city name: sinnamary
# Processing city: 297 city name: hope
# Processing city: 298 city name: shar
# Processing city: 299 city name: salalah
# skip
# Processing city: 301 city name: jumla
# Processing city: 302 city name: talnakh
# Processing city: 303 city name: carutapera
# Processing city: 304 city name: kirkland lake
# Processing city: 305 city name: nova olinda do norte
# Processing city: 306 city name: auki
# Processing city: 307 city name: manakara
# Processing city: 308 city name: mackay
# Processing city: 309 city name: oksfjord
# Processing city: 310 city name: reykjavik
# Processing city: 311 city name: raudeberg
# Processing city: 312 city name: port hedland
# Processing city: 313 city name: bubaque
# Processing city: 314 city name: sweetwater
# skip
# Processing city: 316 city name: kashan
# Processing city: 317 city name: sumenep
# Processing city: 318 city name: ust-kulom
# Processing city: 319 city name: barreirinhas
# Processing city: 320 city name: bira
# Processing city: 321 city name: ancud
# Processing city: 322 city name: igarka
# Processing city: 323 city name: victoria
# Processing city: 324 city name: nelson bay
# skip
# Processing city: 326 city name: hithadhoo
# skip
# Processing city: 328 city name: estevan
# Processing city: 329 city name: nishihara
# Processing city: 330 city name: clyde river
# Processing city: 331 city name: bonavista
# skip
# Processing city: 333 city name: flinders
# Processing city: 334 city name: medea
# Processing city: 335 city name: fairbanks
# skip
# Processing city: 337 city name: carauari
# Processing city: 338 city name: aripuana
# Processing city: 339 city name: asnaes
# Processing city: 340 city name: bonfim
# Processing city: 341 city name: ambon
# Processing city: 342 city name: gold coast
# Processing city: 343 city name: mayo
# Processing city: 344 city name: maumere
# Processing city: 345 city name: mecca
# Processing city: 346 city name: aneho
# Processing city: 347 city name: amapa
# Processing city: 348 city name: nhulunbuy
# Processing city: 349 city name: khudumelapye
# Processing city: 350 city name: ust-maya
# Processing city: 351 city name: russell
# Processing city: 352 city name: broome
# Processing city: 353 city name: khash
# Processing city: 354 city name: diebougou
# Processing city: 355 city name: diego de almagro
# Processing city: 356 city name: grindavik
# Processing city: 357 city name: sitka
# Processing city: 358 city name: maud
# Processing city: 359 city name: airai
# Processing city: 360 city name: vila velha
# Processing city: 361 city name: labuhan
# Processing city: 362 city name: saint-augustin
# Processing city: 363 city name: farah
# Processing city: 364 city name: sao jose do rio pardo
# Processing city: 365 city name: berlevag
# Processing city: 366 city name: red deer
# Processing city: 367 city name: smolyaninovo
# Processing city: 368 city name: vostok
# Processing city: 369 city name: alta floresta
# Processing city: 370 city name: san felipe
# Processing city: 371 city name: olafsvik
# Processing city: 372 city name: mahibadhoo
# Processing city: 373 city name: road town
# Processing city: 374 city name: saint-francois
# Processing city: 375 city name: nadym
# skip
# Processing city: 377 city name: chubbuck
# Processing city: 378 city name: fethiye
# Processing city: 379 city name: alofi
# Processing city: 380 city name: pevek
# Processing city: 381 city name: bereslavka
# Processing city: 382 city name: anjozorobe
# Processing city: 383 city name: axim
# Processing city: 384 city name: omboue
# Processing city: 385 city name: gornoye loo
# Processing city: 386 city name: chauk
# Processing city: 387 city name: beringovskiy
# Processing city: 388 city name: zambezi
# Processing city: 389 city name: kyra
# Processing city: 390 city name: yarmouth
# Processing city: 391 city name: svetlogorsk
# Processing city: 392 city name: comodoro rivadavia
# Processing city: 393 city name: kathmandu
# Processing city: 394 city name: esperance
# Processing city: 395 city name: san juan
# Processing city: 396 city name: port hope
# Processing city: 397 city name: gayny
# Processing city: 398 city name: acapulco
# Processing city: 399 city name: flin flon
# Processing city: 400 city name: panjakent
# Processing city: 401 city name: san cristobal
# Processing city: 402 city name: springbok
# Processing city: 403 city name: batagay
# Processing city: 404 city name: constitucion
# Processing city: 405 city name: yerofey pavlovich
# Processing city: 406 city name: aklavik
# Processing city: 407 city name: luderitz
# Processing city: 408 city name: rocha
# skip
# Processing city: 410 city name: pitsunda
# Processing city: 411 city name: pochutla
# Processing city: 412 city name: struer
# Processing city: 413 city name: dali
# Processing city: 414 city name: narsaq
# Processing city: 415 city name: kalmunai
# Processing city: 416 city name: saldanha
# Processing city: 417 city name: deogarh
# Processing city: 418 city name: kiunga
# Processing city: 419 city name: uyskoye
# Processing city: 420 city name: giyani
# skip
# Processing city: 422 city name: ouango
# Processing city: 423 city name: bukachacha
# Processing city: 424 city name: atar
# Processing city: 425 city name: yakeshi
# Processing city: 426 city name: benghazi
# Processing city: 427 city name: ostersund
# Processing city: 428 city name: suarez
# Processing city: 429 city name: aykhal
# Processing city: 430 city name: kemijarvi
# Processing city: 431 city name: hami
# Processing city: 432 city name: toguchin
# Processing city: 433 city name: mezhdurechenskiy
# Processing city: 434 city name: ishigaki
# Processing city: 435 city name: bonanza
# Processing city: 436 city name: corinto
# Processing city: 437 city name: ascension
# Processing city: 438 city name: cururupu
# Processing city: 439 city name: mahon
# Processing city: 440 city name: jalu
# Processing city: 441 city name: barcelos
# Processing city: 442 city name: kasiri
# skip
# Processing city: 444 city name: atherton
# Processing city: 445 city name: urumqi
# Processing city: 446 city name: batagay-alyta
# Processing city: 447 city name: shebunino
# Processing city: 448 city name: leh
# skip
# Processing city: 450 city name: yumen
# Processing city: 451 city name: naze
# Processing city: 452 city name: marand
# Processing city: 453 city name: bayangol
# Processing city: 454 city name: varhaug
# Processing city: 455 city name: strezhevoy
# Processing city: 456 city name: srednekolymsk
# Processing city: 457 city name: roebourne
# Processing city: 458 city name: pontes e lacerda
# skip
# Processing city: 460 city name: mandalgovi
# Processing city: 461 city name: anshun
# Processing city: 462 city name: elat
# Processing city: 463 city name: dakar
# Processing city: 464 city name: westport
# Processing city: 465 city name: mount gambier
# Processing city: 466 city name: claresholm
# Processing city: 467 city name: port hawkesbury
# Processing city: 468 city name: carballo
# Processing city: 469 city name: viesca
# Processing city: 470 city name: kruisfontein
# skip
# Processing city: 472 city name: boyolangu
# Processing city: 473 city name: villazon
# Processing city: 474 city name: brigantine
# Processing city: 475 city name: cockburn town
# Processing city: 476 city name: turkmenabat
# Processing city: 477 city name: pisco
# Processing city: 478 city name: port macquarie
# Processing city: 479 city name: tabou
# Processing city: 480 city name: kytmanovo
# Processing city: 481 city name: vao
# Processing city: 482 city name: richards bay
# skip
# Processing city: 484 city name: roald
# Processing city: 485 city name: lamar
# Processing city: 486 city name: nouadhibou
# Processing city: 487 city name: suclayin
# Processing city: 488 city name: maragogi
# Processing city: 489 city name: husavik
# Processing city: 490 city name: lae
# Processing city: 491 city name: camamu
# Processing city: 492 city name: tibati
# Processing city: 493 city name: san pedro
# Processing city: 494 city name: sandorfalva
# Processing city: 495 city name: pacifica
# Processing city: 496 city name: berdigestyakh
# skip
# Processing city: 498 city name: hualmay
# Processing city: 499 city name: shiyan
# Processing city: 500 city name: ust-ordynskiy
# Processing city: 501 city name: talara
# Processing city: 502 city name: inhambane
# Processing city: 503 city name: sao jose de ribamar
# Processing city: 504 city name: liuzhou
# Processing city: 505 city name: sao joao da barra
# Processing city: 506 city name: panama city
# skip
# Processing city: 508 city name: ati
# Processing city: 509 city name: maun
# Processing city: 510 city name: altamont
# Processing city: 511 city name: maceio
# Processing city: 512 city name: grand-lahou
# Processing city: 513 city name: rancharia
# Processing city: 514 city name: hovd
# Processing city: 515 city name: honiara
# Processing city: 516 city name: zhigansk
# Processing city: 517 city name: marawi
# skip
# Processing city: 519 city name: hit
# Processing city: 520 city name: bandarbeyla
# Processing city: 521 city name: altos
# skip
# Processing city: 523 city name: saint-georges
# skip
# Processing city: 525 city name: bahir dar
# Processing city: 526 city name: goderich
# Processing city: 527 city name: vila
# Processing city: 528 city name: dafeng
# Processing city: 529 city name: rome
# Processing city: 530 city name: sydney
# Processing city: 531 city name: yuzhno-kurilsk
# Processing city: 532 city name: harsin
# Processing city: 533 city name: turbat
# Processing city: 534 city name: isla mujeres
# Processing city: 535 city name: sayyan
# Processing city: 536 city name: sterling
# Processing city: 537 city name: north bend
# skip
# Processing city: 539 city name: kazachinskoye
# Processing city: 540 city name: san juan de arama
# Processing city: 541 city name: aranos
# Processing city: 542 city name: reyes
# Processing city: 543 city name: la ronge
# Processing city: 544 city name: fort-shevchenko
# skip
# Processing city: 546 city name: bodden town
# Processing city: 547 city name: puyang
# Processing city: 548 city name: shubarkuduk
# Processing city: 549 city name: mvomero
# Processing city: 550 city name: sambava
# Processing city: 551 city name: altay
# Processing city: 552 city name: tevaitoa
# Processing city: 553 city name: wanlaweyn
# Processing city: 554 city name: honolulu
# Processing city: 555 city name: high level
# Processing city: 556 city name: canton
# Processing city: 557 city name: gat
# Processing city: 558 city name: susaki
# skip
# Processing city: 560 city name: zhigalovo
# Processing city: 561 city name: coquimbo
# Processing city: 562 city name: ajra
# Processing city: 563 city name: dhidhdhoo
# Processing city: 564 city name: lusambo
# Processing city: 565 city name: umm lajj
# Processing city: 566 city name: tuatapere
# Processing city: 567 city name: padrauna
# Processing city: 568 city name: sorland
# Processing city: 569 city name: nesna
# Processing city: 570 city name: verkhovazhye
# Processing city: 571 city name: lasa
# Processing city: 572 city name: kuytun
# Processing city: 573 city name: mitzic
# Processing city: 574 city name: kavieng
# Processing city: 575 city name: tezu
# Processing city: 576 city name: sharjah
# Processing city: 577 city name: la foa
# Processing city: 578 city name: lokosovo
# Processing city: 579 city name: khrebtovaya
# skip
# Processing city: 581 city name: san patricio
# Processing city: 582 city name: haines junction
# Processing city: 583 city name: tchamba
# skip
# Processing city: 585 city name: imeni poliny osipenko
# Processing city: 586 city name: belmonte
# Processing city: 587 city name: itarema
# Processing city: 588 city name: miandrivazo
# Processing city: 589 city name: ritchie
# Processing city: 590 city name: acajutla
# Processing city: 591 city name: kiama
# Processing city: 592 city name: sampit
# Processing city: 593 city name: macusani
# Processing city: 594 city name: qobustan
# Processing city: 595 city name: quelimane
# Processing city: 596 city name: terra santa
# Processing city: 597 city name: dalvik
# Processing city: 598 city name: fort nelson
# Processing city: 599 city name: burgeo
# Processing city: 600 city name: klaksvik
# Processing city: 601 city name: mandera
# Processing city: 602 city name: warrington
# Processing city: 603 city name: tazovskiy
# Processing city: 604 city name: lata
# Processing city: 605 city name: suntar
# Processing city: 606 city name: whitehorse
# Processing city: 607 city name: xinzhou
# Processing city: 608 city name: cap malheureux
# Processing city: 609 city name: mitchell
# Processing city: 610 city name: lyuban
# Processing city: 611 city name: changji
# Processing city: 612 city name: dire
# Processing city: 613 city name: harper
# Processing city: 614 city name: maymyo
# Processing city: 615 city name: panalingaan
# Processing city: 616 city name: lima
# Processing city: 617 city name: leningradskiy
# Processing city: 618 city name: padang
# Processing city: 619 city name: kolobrzeg
# Processing city: 620 city name: maniitsoq
# skip
# Processing city: 622 city name: ayan

# %%
city_dict={
    "city": cityname,
    "city id": cityid,
    "Latitude": lat,
    "Longitude": lon,
    "Temperature": temp,
    "Humidity": humidity,
    "Cloudy": cloudy,
    "Wind Speed (mph)": wind}
city_df= pd.DataFrame(city_dict)
city_df.count
# Out:
# <bound method DataFrame.count of                city  city id  Latitude  Longitude  Temperature  Humidity  \
# 0       Verkhoyansk  2013465   67.5447   133.3850       258.80        89
# 1       Verkhoyansk  2013465   67.5447   133.3850       258.80        89
# 2       Verkhoyansk  2013465   67.5447   133.3850       258.80        89
# 3       Verkhoyansk  2013465   67.5447   133.3850       258.80        89
# 4       Verkhoyansk  2013465   67.5447   133.3850       258.80        89
# ...             ...      ...       ...        ...          ...       ...
# 1201  Leningradskiy  2123814   69.3833   178.4167        34.25        74
# 1202         Padang  1633419   -0.9492   100.3543        75.20        94
# 1203      Kołobrzeg  3095795   54.1757    15.5834        43.00        73
# 1204      Maniitsoq  3421982   65.4167   -52.9000        34.18        68
# 1205           Ayan  2027316   56.4500   138.1667        31.55        85
#
#             Cloudy  Wind Speed (mph)
# 0      {'all': 83}              1.65
# 1      {'all': 83}              1.65
# 2      {'all': 83}              1.65
# 3      {'all': 83}              1.65
# 4      {'all': 83}              1.65
# ...            ...               ...
# 1201   {'all': 90}              2.04
# 1202   {'all': 40}              1.14
# 1203    {'all': 4}             14.56
# 1204    {'all': 8}              4.12
# 1205  {'all': 100}              5.59
#
# [1206 rows x 8 columns]>

# %%
clean_city_df= city_df.drop_duplicates(subset=["city"])
# Out:
#                city  city id  Latitude  Longitude  Temperature  Humidity  \
# 0       Verkhoyansk  2013465   67.5447   133.3850       258.80        89
# 623           Bluff  2206939  -46.6000   168.3333        48.99        98
# 624        Khatanga  2022572   71.9667   102.5000        26.65        97
# 625       Busselton  2075265  -33.6500   115.3333        55.11        83
# 626         Rikitea  4030556  -23.1203  -134.9692        78.08        75
# ...             ...      ...       ...        ...          ...       ...
# 1201  Leningradskiy  2123814   69.3833   178.4167        34.25        74
# 1202         Padang  1633419   -0.9492   100.3543        75.20        94
# 1203      Kołobrzeg  3095795   54.1757    15.5834        43.00        73
# 1204      Maniitsoq  3421982   65.4167   -52.9000        34.18        68
# 1205           Ayan  2027316   56.4500   138.1667        31.55        85
#
#             Cloudy  Wind Speed (mph)
# 0      {'all': 83}              1.65
# 623   {'all': 100}              7.00
# 624    {'all': 99}              6.55
# 625    {'all': 94}              1.99
# 626    {'all': 81}             16.33
# ...            ...               ...
# 1201   {'all': 90}              2.04
# 1202   {'all': 40}              1.14
# 1203    {'all': 4}             14.56
# 1204    {'all': 8}              4.12
# 1205  {'all': 100}              5.59
#
# [583 rows x 8 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
